# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeanvaes/learning/blob/main/ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
file_list=os.listdir("/content")
file_list
# Out:
# ['.config',
#  'm_Ejemplo.py',
#  'rp4_template.py',
#  'rp4solver310.pyc',
#  'sample_data']

# %%
import rp4solver310 as rp4
from rp4solver310 import atico
rp4.About()
# Out:
# RP4 Solver Copyright(c) 2022
# Version 6.2 - Beta version
# Developed by Alfonso T. Sarmiento

# %%
problem=atico("m_Ejemplo")
# Out:
# Model m_Ejemplo was imported

# %%
problem.report_GEN_max_states=4
problem.State_Generation() #generador de estados
# Out:
# States generated: 8

# %%
problem.state_space #estados generados
# Out:
# [(1, 1), (2, 1), (2, 2), (2, 0), (3, 1), (3, 2), (3, 0), (3, 4)]

# %%
problem.report_VAI_max_steps=2
V_vector, a_vector=problem.Solution_Process("VAI",2)
# Out:
# Horizon: Finite
# Solved by Value Iteration, All States Based Calculation
# States generated: 8
# Calculating Solution ...
#
# REPORT: SOLUTION PROCESS
# Notation: s=state, V=value function, π=policy's action
#  ■■■■■■■■■■ n= 0 t-steps ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# ==========  s= (1, 1) , V(s)= 0 ============================================================
# ==========  s= (2, 1) , V(s)= 0 ============================================================
# ==========  s= (2, 2) , V(s)= 0 ============================================================
# ==========  s= (2, 0) , V(s)= 0 ============================================================
# ==========  s= (3, 1) , V(s)= 0 ============================================================
# ==========  s= (3, 2) , V(s)= 0 ============================================================
# ==========  s= (3, 0) , V(s)= 0 ============================================================
# ...

# %%
problem.report_VAI_max_steps=2
problem.report_detail=True
V_vector, a_vector=problem.Solution_Process("VAI",2)
# Out:
# Horizon: Finite
# Solved by Value Iteration, All States Based Calculation
# States generated: 8
# Calculating Solution ...
#
# REPORT: SOLUTION PROCESS
# Notation: n=number of t-steps, s=state, V=value function, π=policy's action, a=action, e=event,
#           ca=deterministic contribution, p=transition probability,ce=probabilistic contribution, sn=next state
#  ■■■■■■■■■■ n= 0 t-steps ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# ==========  s= (1, 1) , V(s)= 0 ============================================================
# ==========  s= (2, 1) , V(s)= 0 ============================================================
# ==========  s= (2, 2) , V(s)= 0 ============================================================
# ==========  s= (2, 0) , V(s)= 0 ============================================================
# ==========  s= (3, 1) , V(s)= 0 ============================================================
# ...
